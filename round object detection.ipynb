# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#графики
#%matplotlib inline
#from glob import glob

def flip_list(lst):
    if not lst:
        return lst

    is_vertical = isinstance(lst[0], list)

    if is_vertical:
        return [el[0] for el in lst]

    return [[el] for el in lst]

mas = []# массив со значениями координат центра(x,y) и радиуса найденного тела
m=[]# массив с номерами текущих кадров, в которых зафиксировано тело
x1=700
x2=800
y1=420
y2=520
n=0
# создадим объект VideoCapture для захвата видео
cap = cv2.VideoCapture('/content/11_10_2023_14_53_33.avi')

# Если не удалось открыть файл, выводим сообщение об ошибке
if cap.isOpened() == False:
    print('Не возможно открыть файл')

# Пока файл открыт
while cap.isOpened():
    # поочередно считываем кадры видео
    fl, img = cap.read()
    n+=1
    # если кадры закончились, совершаем выход
    if img is None:
        break
    # if (n>1):
    #     break
    # выводим текущий кадр на экран
    #cv2.imshow("Cat", img)
    # при нажатии клавиши "q", совершаем выход
    if cv2.waitKey(25) == ord('q'):
        break
    # Read image.
    # img = cv2.imread(img, cv2.IMREAD_COLOR)
    img=img[y1:y2,x1:x2]
    # Convert to grayscale.
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Blur using 3 * 3 kernel.
    gray_blurred = cv2.blur(gray, (3, 3))
    # cv2_imshow( gray_blurred)

    # Apply Hough transform on the blurred image.
    detected_circles = cv2.HoughCircles(gray_blurred,
            cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
          param2 = 30, minRadius = 1, maxRadius = 400)
      # Draw circles that are detected.
    if detected_circles is not None:
      print(n)
      #запись в массив значений
      mas.extend(detected_circles[ :,0])
      m.extend([n])# n - номер текущего кадра
      # Визуализация найденного кружка на img
    #   # Convert the circle parameters a, b and r to integers. для отрисовки
    #   detected_circles = np.uint16(np.around(detected_circles))

    #   for pt in detected_circles[0, :]:
    #     a, b, r = pt[0], pt[1], pt[2]

    #     # Draw the circumference of the circle.
    #     cv2.circle(img, (a, b), r, (0, 255, 0), 2)

    #     # Draw a small circle (of radius 1) to show the center.
    #     cv2.circle(img, (a, b), 1, (0, 0, 255), 3)

    #     imgs.extend(img)

# освобождаем память от переменной cap
cap.release()
# закрываем все открытые opencv окна
cv2.destroyAllWindows()

# добавление к коордиматам значений, которые мы обрезали сверху
# for i in range(0, len(mas)):
#   mas[i][1] += x1

#запись в эксель
m=flip_list(m)#переворот m из горизонт в вертик
k = np.append(np.array(mas), np.array(m), axis= 1 )
df =pd.DataFrame(k)
df.to_excel(excel_writer = "/content/krug.xlsx",)
print("количество кадров = ", n-1)
# Out:
# 88
# 89
# 92
# 93
# 98
# 100
# 102
# 104
# 105
# 109
# 115
# 116
# 118
# 119
# 120
# 122
# 124
# 125
# 127
# <PIL.Image.Image image mode=L size=100x100>
# количество кадров =  136

# %%
Data=pd.read_excel('/content/krug.xlsx', index_col=0)
t=Data[3]#время - номер кадра
x=Data[1]#x -координата x центра шара
y = Data[0].apply(lambda x: x*-1)

# %%
img = cv2.imread('/content/fil.jpg')
img=img[y1:,x1:x2]
plt.imshow(img)

plt.show()

# %%
plt.plot(t, x )
plt.grid(True)

# %%
plt.plot(t, y )
plt.grid(True)

# %%
plt.plot(x, y )
plt.grid(True)

# %% [markdown]
# ##чтение одного кадра для подбора параметров для обрезки изображения

# %%
# импортируем модуль opencv
import cv2
from google.colab.patches import cv2_imshow
# создадим объект VideoCapture для захвата видео
cap = cv2.VideoCapture('/content/11_10_2023_14_53_33.avi')

# Если не удалось открыть файл, выводим сообщение об ошибке
if cap.isOpened() == False:
    print('Не возможно открыть файл')
n=0
# Пока файл открыт
while cap.isOpened():
  n+=1
  # поочередно считываем кадры видео
  fl, img = cap.read()
    # если кадры закончились, совершаем выход
  if img is None:
      break
  if (n>1):
      break
    # выводим текущий кадр на экран
  img=img[420:520,700:800]
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  cv2_imshow( img)
    # при нажатии клавиши "q", совершаем выход
  if cv2.waitKey(25) == ord('q'):
      break

# освобождаем память от переменной cap
cap.release()
# закрываем все открытые opencv окна
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# #2 способ(пока забили- решаем проблему аппаратно-ищем норм свет )

# %%
pip install cv

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv
from google.colab.patches import cv2_imshow
#графики
#%matplotlib inline
#from glob import glob

def flip_list(lst):
    if not lst:
        return lst

    is_vertical = isinstance(lst[0], list)

    if is_vertical:
        return [el[0] for el in lst]

    return [[el] for el in lst]

mas = []# массив со значениями координат центра(x,y) и радиуса найденного тела
m=[]# массив с номерами текущих кадров, в которых зафиксировано тело
x1=700
x2=800
y1=420
y2=520
n=0

# создадим объект VideoCapture для захвата видео
cap = cv2.VideoCapture('/content/11_10_2023_14_53_33.avi')

# Если не удалось открыть файл, выводим сообщение об ошибке
if cap.isOpened() == False:
    print('Не возможно открыть файл')

# Пока файл открыт
while cap.isOpened():
    # поочередно считываем кадры видео
    fl, img = cap.read()
    n+=1
    # если кадры закончились, совершаем выход
    if img is None:
        break

    # при нажатии клавиши "q", совершаем выход
    if cv2.waitKey(25) == ord('q'):
        break
    if (n>1):
         break
    # Read image.
    # img = cv2.imread(img, cv2.IMREAD_COLOR)
    img=img[y1:y2,x1:x2]

    # hsv - Hue, Saturation, Value — тон, насыщенность, значение
    # меняем цветовую модель с BGR на HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)    # меняем цветовую модель с BGR на HSV
    # Создание маски на изображение, чтобы исключить ложные объекты
    hsv_min = np.array((0, 0, 168), np.uint8)    # нижняя граница
    hsv_max = np.array((255, 255, 255), np.uint8)  # верхняя граница
    mask = cv2.inRange(hsv, hsv_min, hsv_max)    # применяем цветовой фильтр
    # меняем цветовую модель с BGR на RGB для привычного отображения
      # меняем цветовую модель с BGR на RGB для привычного отображения
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2_imshow(mask)
    # ищем все контуры
    contours, hierarchy = cv2.findContours(mask.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # # cv2.approxPloyDP() function to approximate the shape
    # approx = cv2.approxPolyDP(
    #     contour, 0.01 * cv2.arcLength(contour, True), True)

    # # using drawContours() function
    # cv2.drawContours(img, [contour], 0, (0, 0, 255), 5)

    # # finding center point of shape
    # M = cv2.moments(contour)
    # if M['m00'] != 0.0:
    #     x = int(M['m10']/M['m00'])
    #     y = int(M['m01']/M['m00'])

    # # putting shape name at center of each shape
    # if len(approx) == 3:
    #     cv2.putText(img, 'Triangle', (x, y),
    #                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    # elif len(approx) == 4:
    #     cv2.putText(img, 'Quadrilateral', (x, y),
    #                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    # elif len(approx) == 5:
    #     cv2.putText(img, 'Pentagon', (x, y),
    #                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    # elif len(approx) == 6:
    #     cv2.putText(img, 'Hexagon', (x, y),
    #                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    # else:
    #     cv2.putText(img, 'circle', (x, y),
    #                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

# displaying the image after drawing contours
cv2.imshow('shapes', img)


  # перебираем все найденные контуры в цикле и ищем прямоугольники
    for cnt in contours:
      cv2.drawContours(img,cnt,0,(255,0,0),2)
      plt.show()
      print('что то нашел')








# освобождаем память от переменной cap
cap.release()
# закрываем все открытые opencv окна
cv2.destroyAllWindows()

# добавление к коордиматам значений, которые мы обрезали сверху
# for i in range(0, len(mas)):
#   mas[i][1] += x1

#запись в эксель
m=flip_list(m)#переворот m из горизонт в вертик
k = np.append(np.array(mas), np.array(m), axis= 0 )
df =pd.DataFrame(k)
df.to_excel(excel_writer = "/content/krug.xlsx",)
print("количество кадров = ", n-1)
# Out:
# <PIL.Image.Image image mode=L size=100x100>
# что то нашел
# что то нашел
# что то нашел
# что то нашел
# что то нашел
# что то нашел
# что то нашел
# количество кадров =  1
